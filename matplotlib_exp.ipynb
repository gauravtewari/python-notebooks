# %%
print("Hello")
# Out:
# Hello

# %%
from matplotlib import pyplot as plt

# %%
l=[1,2,3,4,5]
plt.plot(l)
plt.show()

# %%
plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.axvline(0.5)

# %%
plt.axhline(0.5)

# %%
plt.plot([20,25,44,78, 90])
plt.axhline(50)
plt.axvline(2)
plt.title("Testing")
plt.show()
